# %%
import numpy as np
import matplotlib.pyplot as plt
from rcFun import *

# %%
# params (that you might want to automate)

jumpOps = ['S_Z', 'S_minus']
name = jumpOps[1]
p = '0.1'
r = '10.0'
N = '10'

homepath='RC_raw/'
S1 = np.loadtxt(homepath + 'S1_' + name + '_p=' + str(p) + '_r=' + str(r) + '_N=' + str(N) + '.out')
S2 = np.loadtxt(homepath + 'S2_' + name + '_p=' + str(p) + '_r=' + str(r) + '_N=' + str(N)  + '.out')
Stot = np.loadtxt(homepath + 'Stot_' + name + '_p=' + str(p) + '_r=' + str(r) + '_N=' + str(N)  + '.out')
I = np.loadtxt(homepath + 'I_' + name + '_p=' + str(p) + '_r=' + str(r) + '_N=' + str(N) + '.out')
purity = np.loadtxt(homepath + 'purity_' + name + '_p=' + str(p) + '_r=' + str(r) + '_N=' + str(N) + '.out')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-e25ae0153fbf> in <module>
#       8
#       9 homepath='RC_raw/'
# ---> 10 S1 = np.loadtxt(homepath + 'S1_' + name + '_p=' + str(p) + '_r=' + str(r) + '_N=' + str(N) + '.out')
#      11 S2 = np.loadtxt(homepath + 'S2_' + name + '_p=' + str(p) + '_r=' + str(r) + '_N=' + str(N)  + '.out')
#      12 Stot = np.loadtxt(homepath + 'Stot_' + name + '_p=' + str(p) + '_r=' + str(r) + '_N=' + str(N)  + '.out')
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     959             fname = os_fspath(fname)
#     960         if _is_string_like(fname):
# --> 961             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     962             fencoding = getattr(fh, 'encoding', 'latin1')
# ...

# %%
plt.figure()
plt.plot(np.average(S1, axis=0))
plt.plot(np.average(S2, axis=0))
plt.plot(np.average(Stot, axis=0))
plt.plot(np.average(I, axis=0))


plt.figure()
plt.plot(np.average(purity, axis=0))

# %%
plt.figure()
for j in range(2):
    plt.plot(purity[j,:])

# %%
# params (that you might want to automate)

jumpOps = ['S_Z', 'S_minus']
name = jumpOps[1]
p = '0.1'
r = '0.001'
N = '8'


homepath='RC_raw/'
S1 = np.loadtxt(homepath + 'S1_' + name + '_p=' + str(p) + '_r=' + str(r) + '_N=' + str(N) + '.out')
S2 = np.loadtxt(homepath + 'S2_' + name + '_p=' + str(p) + '_r=' + str(r) + '_N=' + str(N)  + '.out')
Stot = np.loadtxt(homepath + 'Stot_' + name + '_p=' + str(p) + '_r=' + str(r) + '_N=' + str(N)  + '.out')
I = np.loadtxt(homepath + 'I_' + name + '_p=' + str(p) + '_r=' + str(r) + '_N=' + str(N) + '.out')
purity = np.loadtxt(homepath + 'purity_' + name + '_p=' + str(p) + '_r=' + str(r) + '_N=' + str(N) + '.out')

# %%
plt.figure()
plt.plot(np.average(S1, axis=0))
plt.plot(np.average(S2, axis=0))
plt.plot(np.average(Stot, axis=0))
plt.plot(np.average(I, axis=0))
plt.legend(['S1','S2','S_tot','I'])


plt.figure()
plt.plot(np.average(purity, axis=0))

# %%
# params (that you might want to automate)

jumpOps = ['S_Z', 'S_minus']
name = jumpOps[1]
p = '0.1'
r = '1e-05'
N = '8'


homepath='RC_raw/'
S1 = np.loadtxt(homepath + 'S1_' + name + '_p=' + str(p) + '_r=' + str(r) + '_N=' + str(N) + '.out')
S2 = np.loadtxt(homepath + 'S2_' + name + '_p=' + str(p) + '_r=' + str(r) + '_N=' + str(N)  + '.out')
Stot = np.loadtxt(homepath + 'Stot_' + name + '_p=' + str(p) + '_r=' + str(r) + '_N=' + str(N)  + '.out')
I = np.loadtxt(homepath + 'I_' + name + '_p=' + str(p) + '_r=' + str(r) + '_N=' + str(N) + '.out')
purity = np.loadtxt(homepath + 'purity_' + name + '_p=' + str(p) + '_r=' + str(r) + '_N=' + str(N) + '.out')

# %%
plt.figure()
plt.plot(np.average(S1, axis=0))
plt.plot(np.average(S2, axis=0))
plt.plot(np.average(Stot, axis=0))
plt.plot(np.average(I, axis=0))


plt.figure()
plt.plot(np.average(purity, axis=0))
